# %%
# magic command for interactive plot (very cool but very laggy)
#%matplotlib ipympl
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in the data and print summary statisitcs
file = "/home2/cbsuenbody/reg259/finch_genome_imputation/example_project/results/depth_stats.csv"
data = pd.read_csv(file, sep=",")
data[data["chr"] != "chrZ"]["mean"].describe()
# Out:
# count    6641.000000
# mean        3.183200
# std         0.594643
# min         1.453739
# 25%         2.785390
# 50%         3.016327
# 75%         3.517251
# max         5.655865
# Name: mean, dtype: float64

# %%
# look at a read depth histogram (without chr Z)
data[data["chr"] != "chrZ"]["mean"].hist(bins=50)
plt.xlabel("Read Depth")
plt.ylabel("Count")
plt.show()

# %%
# read in the data and print summary statisitcs
file = "/home2/cbsuenbody/reg259/finch_genome_imputation/example_project/results/avg_depth_sample.csv"
data = pd.read_csv(file, sep=",")
data["wt_avg"].describe()
# Out:
# count    229.000000
# mean       3.060441
# std        0.504312
# min        1.539676
# 25%        2.728446
# 50%        2.922642
# 75%        3.329383
# max        4.982312
# Name: wt_avg, dtype: float64

# %%
# look at a read depth histogram (weighted averages)
data["wt_avg"].hist(bins=50)
plt.xlabel("Read Depth")
plt.ylabel("Count")
plt.show()
